# %%
from __future__ import print_function, division

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline

# %%
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [190907, 190914, 190921, 190928, 191005, 191012, 191019, 191026, 191102, 191109, 191116, 191123, 191130]
turnstiles_df = get_data(week_nums)

# %%
turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns]

# %%
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " + turnstiles_df.TIME, 
                                            format="%m/%d/%Y %H:%M:%S")

# %%
# Get rid of the duplicate entries
turnstiles_df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], 
                          inplace=True, ascending=False)
turnstiles_df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#           C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 0        A002  R051  02-00-00           59 ST 2019-08-31 00:00:00        1
# 1784129  R138  R293  00-02-05  34 ST-PENN STA 2019-09-11 06:00:00        1
# 1784111  R138  R293  00-02-05  34 ST-PENN STA 2019-09-08 06:00:00        1
# 1784112  R138  R293  00-02-05  34 ST-PENN STA 2019-09-08 10:00:00        1
# 1784113  R138  R293  00-02-05  34 ST-PENN STA 2019-09-08 14:00:00        1

# %%
# Drop Exits and Desc Column.  To prevent errors in multiple run of cell, errors on drop is ignored
turnstiles_df = turnstiles_df.drop(["EXITS", "DESC"], axis=1, errors="ignore")

# %%
turnstiles_daily = (turnstiles_df
                        .groupby(["C/A", "UNIT", "SCP", "STATION", "LINENAME", "DATE"],as_index=False)
                        .ENTRIES.first())

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME        DATE  ENTRIES
# 0  A002  R051  02-00-00   59 ST  NQR456W  08/31/2019  7183842
# 1  A002  R051  02-00-00   59 ST  NQR456W  09/01/2019  7184559
# 2  A002  R051  02-00-00   59 ST  NQR456W  09/02/2019  7185132
# 3  A002  R051  02-00-00   59 ST  NQR456W  09/03/2019  7186355
# 4  A002  R051  02-00-00   59 ST  NQR456W  09/04/2019  7187672

# %%
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION", "LINENAME"])["DATE", "ENTRIES"]
                                                       .apply(lambda grp: grp.shift(1)))
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]].head()
# Out:
#        C/A  UNIT       SCP     STATION LINENAME        DATE    ENTRIES  \
# 3530  A011  R080  01-03-00  57 ST-7 AV     NQRW  09/01/2019  885822693
# 3531  A011  R080  01-03-00  57 ST-7 AV     NQRW  09/02/2019  885822365
# 3532  A011  R080  01-03-00  57 ST-7 AV     NQRW  09/03/2019  885821627
# 3533  A011  R080  01-03-00  57 ST-7 AV     NQRW  09/04/2019  885820824
# 3534  A011  R080  01-03-00  57 ST-7 AV     NQRW  09/05/2019  885819992
#
#        PREV_DATE  PREV_ENTRIES
# 3530  08/31/2019   885823072.0
# 3531  09/01/2019   885822693.0
# 3532  09/02/2019   885822365.0
# 3533  09/03/2019   885821627.0
# 3534  09/04/2019   885820824.0

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
_ = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 12 6170034.0
# 263 3846402.0
# 29 3367836.0
# 26 1083967.0
# 864 2152170.0
# 111 1599317.0
# 460501 6804909.0
# 73 6697765.0
# 875479599 775219651.0
# 590597 9156558.0
# 88 2728627.0
# 94 4283110.0
# 1041 2210879.0
# 98 1478936.0
# 116 6197971.0
# 66 1121336148.0
# 82 2025847506.0
# 1451 4711879.0
# 973 6844908.0
# 126 6053205.0
# 196612 50345125.0
# 589824 50331648.0
# 5421 10392294.0
# 2157 6026406.0
# 458752 117440512.0
# 107 1068192.0
# 2567 152966689.0
# 2204 19783118.0
# 458752 117440512.0
# 24 2781046.0
# 3728 1842366.0
# 2069 4443445.0
# 178 6625781.0
# 4982302 877264.0
# 1421 2254274.0
# 721441460 2880424.0
# 516 3275592.0
# 610 2460400.0
# 14 4584512.0
# 26 153536031.0
# 18 118621565.0
# 67122955 103584.0
# 218 67122955.0
# 458846 2297063.0
# 672 5491989.0
# 235398290 9934.0
# 83886083 117440614.0
# 10 5679392.0
# 1145 4459356.0
# 6817688 3603909.0
# 401 3071806.0
# 123785342 117604971.0
# 636 2209128.0
# 31260681 48404.0
# 1507856 4609.0
# 2053 3512072.0
# 483 4777140.0
# 102459350 210849.0
# 248 3782823.0
# 248 9852706.0
# 1 134218317.0
# 2319 22554564.0
# 190 1449873.0
# 3480 5391681.0
# 845 17297548.0
# 2528 2885384.0
# 15753262 3953152.0
# 3953156 15763173.0
# 39242377 15747786.0
# 15764523 39256787.0
# 569320809 779039.0
# 850 703406488.0
# 1711290743 6741160.0
# 10281 5196826.0
# 5198042 1005308.0
# 352351910 1425732.0
# 722 2242009.0
# 1840 9112633.0
# 33601225 187583.0
# 16730515 453031795.0
# 1761654061 6924162.0
# 1560341960 6151899.0
# 285275114 1162483.0
# 8 3319600.0
# 268448218 1063972.0
# 2046772953 8817079.0
# 139432168 1325952449.0
# 5 2013355755.0
# 811 3673993.0
# 1534 991539550.0
# 7035 5634647.0
# 1142 3303158.0
# 1117457 3429648.0
# 891 12274152.0

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter
    if counter > max_counter:
        # Maybe counter was reset to 0? 
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
# It'd probably be a good idea to use a number even significantly smaller than 1 million as the limit!
turnstiles_daily["DAILY_ENTRIES"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 12 6170034.0
# 263 3846402.0
# 29 3367836.0
# 26 1083967.0
# 864 2152170.0
# 111 1599317.0
# 460501 6804909.0
# 73 6697765.0
# 875479599 775219651.0
# 590597 9156558.0
# 88 2728627.0
# 94 4283110.0
# 1041 2210879.0
# 98 1478936.0
# 116 6197971.0
# 66 1121336148.0
# 82 2025847506.0
# 1451 4711879.0
# 973 6844908.0
# 126 6053205.0
# 196612 50345125.0
# 589824 50331648.0
# 5421 10392294.0
# 2157 6026406.0
# 458752 117440512.0
# 107 1068192.0
# 2567 152966689.0
# 2204 19783118.0
# 458752 117440512.0
# 24 2781046.0
# 3728 1842366.0
# 2069 4443445.0
# 178 6625781.0
# 4982302 877264.0
# 1421 2254274.0
# 721441460 2880424.0
# 516 3275592.0
# 610 2460400.0
# 14 4584512.0
# 26 153536031.0
# 18 118621565.0
# 67122955 103584.0
# 218 67122955.0
# 458846 2297063.0
# 672 5491989.0
# 235398290 9934.0
# 83886083 117440614.0
# 10 5679392.0
# 1145 4459356.0
# 6817688 3603909.0
# 401 3071806.0
# 123785342 117604971.0
# 636 2209128.0
# 31260681 48404.0
# 1507856 4609.0
# 2053 3512072.0
# 483 4777140.0
# 102459350 210849.0
# 248 3782823.0
# 248 9852706.0
# 1 134218317.0
# 2319 22554564.0
# 190 1449873.0
# 3480 5391681.0
# 845 17297548.0
# 2528 2885384.0
# 15753262 3953152.0
# 3953156 15763173.0
# 39242377 15747786.0
# 15764523 39256787.0
# 569320809 779039.0
# 850 703406488.0
# 1711290743 6741160.0
# 10281 5196826.0
# 5198042 1005308.0
# 352351910 1425732.0
# 722 2242009.0
# 1840 9112633.0
# 33601225 187583.0
# 16730515 453031795.0
# 1761654061 6924162.0
# 1560341960 6151899.0
# 285275114 1162483.0
# 8 3319600.0
# 268448218 1063972.0
# 2046772953 8817079.0
# 139432168 1325952449.0
# 5 2013355755.0
# 811 3673993.0
# 1534 991539550.0
# 7035 5634647.0
# 1142 3303158.0
# 1117457 3429648.0
# 891 12274152.0

# %%
turnstiles_daily
# Out:
#           C/A  UNIT       SCP        STATION LINENAME        DATE  ENTRIES  \
# 1        A002  R051  02-00-00          59 ST  NQR456W  09/01/2019  7184559
# 2        A002  R051  02-00-00          59 ST  NQR456W  09/02/2019  7185132
# 3        A002  R051  02-00-00          59 ST  NQR456W  09/03/2019  7186355
# 4        A002  R051  02-00-00          59 ST  NQR456W  09/04/2019  7187672
# 5        A002  R051  02-00-00          59 ST  NQR456W  09/05/2019  7189025
# ...       ...   ...       ...            ...      ...         ...      ...
# 444786  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R  11/25/2019     5554
# 444787  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R  11/26/2019     5554
# 444788  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R  11/27/2019     5554
# 444789  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R  11/28/2019     5554
# 444790  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R  11/29/2019     5554
#
#          PREV_DATE  PREV_ENTRIES  DAILY_ENTRIES
# 1       08/31/2019     7183842.0          717.0
# 2       09/01/2019     7184559.0          573.0
# 3       09/02/2019     7185132.0         1223.0
# 4       09/03/2019     7186355.0         1317.0
# 5       09/04/2019     7187672.0         1353.0
# ...            ...           ...            ...
# 444786  11/24/2019        5554.0            0.0
# 444787  11/25/2019        5554.0            0.0
# 444788  11/26/2019        5554.0            0.0
# 444789  11/27/2019        5554.0            0.0
# 444790  11/28/2019        5554.0            0.0
#
# [439863 rows x 10 columns]

# %%
stations_total = (turnstiles_daily
                        .groupby(["STATION","LINENAME"],as_index=False).agg("sum")).sort_values("DAILY_ENTRIES", ascending = False).reset_index()
                        #.DAILY_ENTRIES.sum())

# %%
stations_total
# Out:
#      index          STATION      LINENAME       ENTRIES  PREV_ENTRIES  \
# 0      311  GRD CNTRL-42 ST         4567S  226865326108  2.268583e+11
# 1       89  34 ST-HERALD SQ      BDFMNQRW  416207405402  4.161986e+11
# 2      102  42 ST-PORT AUTH  ACENQRS1237W  667469074088  6.674638e+11
# 3      403     PATH NEW WTC             1     414635697  4.136185e+08
# 4       93   34 ST-PENN STA           ACE  150330038840  1.503246e+11
# ..     ...              ...           ...           ...           ...
# 472    449    TOMPKINSVILLE             1     216784555  2.167347e+08
# 473    203      BEACH 98 ST            AS     452779551  4.527428e+08
# 474    220    BROAD CHANNEL            AS     130029958  1.300058e+08
# 475    196     BEACH 105 ST            AS   10704291634  1.070427e+10
# 476    396    ORCHARD BEACH             6      11383666  1.138358e+07
#
#      DAILY_ENTRIES
# 0       12458229.0
# 1        9979861.0
# 2        7175885.0
# 3        6878013.0
# 4        6548407.0
# ..             ...
# 472        49882.0
# 473        36755.0
# 474        24181.0
# 475        18738.0
# 476           89.0
#
# [477 rows x 6 columns]

# %%
stations_zips = pd.read_csv("sub_st_zip.csv")

# %%
stations_zips.rename(columns={'Stop Name':'STATION', "Zip Code":"ZipCode"}, inplace = True)

# %%
stations_zips.STATION = stations_zips.STATION.str.upper()

# %%
manh_stations=stations_zips.STATION.to_list()

# %%
len(manh_stations)
# Out:
# 153

# %%
manh_stations_total = stations_total[stations_total["STATION"].isin(manh_stations)]

# %%
manh_stations_total
# Out:
#      index    STATION  LINENAME       ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# 8      301  FULTON ST  2345ACJZ  141641492745  1.416370e+11      5303970.0
# 14     234   CANAL ST   JNQRZ6W  275657025992  2.756537e+11      3935409.0
# 15     138      72 ST       123   68243510585  6.824090e+10      3607329.0
# 16     156      86 ST       456  119545892760  1.195424e+11      3518649.0
# 18     121      59 ST   456NQRW  151409177842  1.521094e+11      3328368.0
# ..     ...        ...       ...           ...           ...            ...
# 406     30     145 ST         3    1333200594  1.332932e+09       268241.0
# 414    114      50 ST         D    1145424833  1.145171e+09       253611.0
# 425     36     155 ST         C    1479960900  1.479730e+09       230640.0
# 438    158      86 ST         N     451371746  4.511787e+08       193073.0
# 453     67     215 ST         1     703569282  7.034153e+08       153939.0
#
# [107 rows x 6 columns]

# %%
zip_dict  = pd.Series(stations_zips.ZipCode.values,index=stations_zips.STATION).to_dict()

# %%
manh_stations_total["ZipCode"] = manh_stations_total["STATION"].map(zip_dict)
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
manh_stations_total
# Out:
#      index    STATION  LINENAME       ENTRIES  PREV_ENTRIES  DAILY_ENTRIES  \
# 8      301  FULTON ST  2345ACJZ  141641492745  1.416370e+11      5303970.0
# 14     234   CANAL ST   JNQRZ6W  275657025992  2.756537e+11      3935409.0
# 15     138      72 ST       123   68243510585  6.824090e+10      3607329.0
# 16     156      86 ST       456  119545892760  1.195424e+11      3518649.0
# 18     121      59 ST   456NQRW  151409177842  1.521094e+11      3328368.0
# ..     ...        ...       ...           ...           ...            ...
# 406     30     145 ST         3    1333200594  1.332932e+09       268241.0
# 414    114      50 ST         D    1145424833  1.145171e+09       253611.0
# 425     36     155 ST         C    1479960900  1.479730e+09       230640.0
# 438    158      86 ST         N     451371746  4.511787e+08       193073.0
# 453     67     215 ST         1     703569282  7.034153e+08       153939.0
#
#      ZipCode
# 8      10038
# 14     10013
# 15     10021
# 16     10028
# 18     10022
# ..       ...
# 406    10031
# 414    10019
# 425    10018
# 438    10028
# 453    10018
#
# [107 rows x 7 columns]

# %%
stations_elev = pd.read_csv("Elevator_yes_no.csv")

# %%
manh_stations_total["STATIONLINE"] = manh_stations_total.STATION+manh_stations_total.LINENAME
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pd.set_option('display.max_rows', 200)

# %%
manh_stations_total.sort_values("STATIONLINE")
# Out:
#      index         STATION  LINENAME       ENTRIES  PREV_ENTRIES  \
# 117      0            1 AV         L  108210509971  1.082092e+11
# 171      1          103 ST         1    5901511168  5.900530e+09
# 160      2          103 ST         6    4361693836  4.360641e+09
# 347      3          103 ST        BC    2747657700  2.747271e+09
# 192      7          110 ST         6    3525627318  3.524766e+09
# 127     11          116 ST        23    2694787170  2.694275e+09
# 82      12          116 ST         6    2748222208  2.747402e+09
# 252     13          116 ST        BC   32702585905  3.270199e+10
# 237     16          125 ST         1   59404208111  5.940356e+10
# 129     17          125 ST        23  226436618298  2.264357e+11
# 27      18          125 ST       456  273655268585  2.736526e+11
# 34      19          125 ST      ACBD   45346701364  4.535040e+10
# 147     20          135 ST        23    4436454594  4.435344e+09
# 229     21          135 ST        BC   18639633128  1.863935e+10
# 43      24           14 ST    123FLM  136127995794  1.361266e+11
# 70      25           14 ST      ACEL  194999480548  1.949981e+11
# 87      26           14 ST    FLM123    5106356915  5.104833e+09
# 210     29          145 ST         1   74091606691  7.409084e+10
# 406     30          145 ST         3    1333200594  1.332932e+09
# 55      31          145 ST      ABCD   10532589724  1.053063e+10
# 392     35          155 ST        BD    2015951261  2.015654e+09
# 425     36          155 ST         C    1479960900  1.479730e+09
# 172     37          157 ST         1    2142497183  2.164072e+09
# 83      43          168 ST       AC1    6709367361  6.707825e+09
# 153     49          175 ST         A   34243062582  3.424197e+10
# 187     54           18 ST         1   10632003265  1.052907e+10
# 185     55          181 ST         1    3345058744  3.344148e+09
# 195     56          181 ST         A    5799926889  5.799092e+09
# 337     59          190 ST         A  130850434643  1.308503e+11
# 247     60          191 ST         1     585232902  5.846199e+08
# 101     61            2 AV         F   12302761442  1.230134e+10
# 245     64          207 ST         1   14395618037  1.439524e+10
# 453     67          215 ST         1     703569282  7.034153e+08
# 132     70           23 ST         1    2477874323  2.476675e+09
# 29      71           23 ST         6  185196432085  1.851945e+11
# 60      72           23 ST        CE   20008254244  2.017913e+10
# 33      73           23 ST        FM  279742828485  2.797408e+11
# 47      74           23 ST       NRW   14019555925  1.401814e+10
# 138     80           28 ST         1    3986075205  3.988691e+09
# 84      81           28 ST         6  109394734651  1.093932e+11
# 173     82           28 ST       NRW    3184504629  3.183527e+09
# 331     83            3 AV         L    2334083753  2.333667e+09
# 40      87           33 ST         6  138942743023  1.389408e+11
# 69     107           49 ST      NQRW    7627305602  7.631712e+09
# 58     109      5 AV/53 ST        EM    9509816879  9.507901e+09
# 122    110      5 AV/59 ST      NQRW   12876331822  1.287509e+10
# 50     112           50 ST         1    7985770577  7.983719e+09
# 67     113           50 ST        CE   36401474806  3.639970e+10
# 414    114           50 ST         D    1145424833  1.145171e+09
# 35     115           51 ST         6   54480116595  5.390995e+10
# 118    119           57 ST         F    3193484310  3.192195e+09
# 18     121           59 ST   456NQRW  151409177842  1.521094e+11
# 168    122           59 ST   NQR456W    5107399859  5.106407e+09
# 180    123           59 ST       NRW    1350710638  1.349770e+09
# 334    126            6 AV    FLM123  110323108488  1.103231e+11
# 105    134            7 AV       BDE    3536868087  3.535480e+09
# 211    135            7 AV        BQ    3276278976  3.275511e+09
# 174    136            7 AV        FG    1009319150  1.008353e+09
# 15     138           72 ST       123   68243510585  6.824090e+10
# 212    139           72 ST        BC    2129268409  2.128504e+09
# 51     144           77 ST         6   23524582686  2.352254e+10
# 320    145           77 ST         R    2851118750  2.850682e+09
# 133    146           79 ST         1    3500880266  3.499691e+09
# 285    147           79 ST         D    8894991735  8.894487e+09
# 61     148            8 AV      ACEL   12188020316  1.218616e+10
# 167    149            8 AV         N    1735610308  1.734605e+09
# 100    155           86 ST         1    6078539422  6.077118e+09
# 16     156           86 ST       456  119545892760  1.195424e+11
# 188    157           86 ST        BC    2437442751  2.436545e+09
# 438    158           86 ST         N     451371746  4.511787e+08
# 186    159           86 ST         R   14635479086  1.463457e+10
# 22     164           96 ST       123   14946269851  1.494333e+10
# 108    165           96 ST         6   66002402621  6.600103e+10
# 207    166           96 ST        BC    2759062077  2.758266e+09
# 106    173        ASTOR PL         6    2572775464  2.588696e+09
# 107    212     BLEECKER ST       6DF    3205396132  3.204212e+09
# 353    216          BOWERY        JZ    1541058079  1.540687e+09
# 26     217   BOWLING GREEN        45  213266588540  2.132639e+11
# 251    221        BROAD ST        JZ    1645466543  1.644865e+09
# 151    232        CANAL ST         1    1214606976  1.214674e+09
# 76     233        CANAL ST       ACE   86865726382  8.686407e+10
# 14     234        CANAL ST   JNQRZ6W  275657025992  2.756537e+11
# 169    238  CATHEDRAL PKWY         1    1846625682  1.845633e+09
# 241    239  CATHEDRAL PKWY        BC    8351240895  8.350603e+09
# 80     242     CHAMBERS ST       123  197052584022  1.970545e+11
# 41     243     CHAMBERS ST     ACE23  175021325858  1.750219e+11
# 73     244     CHAMBERS ST     JZ456    7543322459  7.547938e+09
# 322    251       CITY HALL       NRW   30123305561  3.012287e+10
# 85     259    CORTLANDT ST       RNW  235573642819  2.355721e+11
# 268    271      DYCKMAN ST         1     731569566  7.310200e+08
# 261    272      DYCKMAN ST         A    2894751485  2.894181e+09
# 150    277   EAST BROADWAY         F   13818349792  1.381725e+10
# 317    295     FRANKLIN ST         1    2540884517  2.540442e+09
# 8      301       FULTON ST  2345ACJZ  141641492745  1.416370e+11
# 37     302       FULTON ST  ACJZ2345  285343602498  2.853413e+11
# 287    303       FULTON ST         G    1809377642  1.808876e+09
# 36     307        GRAND ST        BD   27226794534  2.722508e+10
# 301    308        GRAND ST         L    1789791275  1.789313e+09
# 142    322      HOUSTON ST         1    3372533374  3.376173e+09
# 158    411       PRINCE ST       NRW    6602786729  6.601721e+09
# 219    418       RECTOR ST         1    1469950155  1.440263e+09
# 283    419       RECTOR ST       NRW   13141018517  1.314051e+10
# 38     433     SOUTH FERRY       1RW   14431932861  1.442424e+10
# 184    434       SPRING ST         6    3220184760  3.224654e+09
# 143    435       SPRING ST        CE   32783498625  3.278237e+10
# 72     462         WALL ST        23   10504197476  1.050245e+10
# 63     463         WALL ST        45   42717492240  4.271651e+10
#
#      DAILY_ENTRIES  ZipCode        STATIONLINE
# 117      1298171.0    10009              1 AVL
# 171       981372.0    10025            103 ST1
# 160      1052643.0    10025            103 ST6
# 347       386482.0    10025           103 STBC
# 192       861425.0    10029            110 ST6
# 127      1223427.0    10035           116 ST23
# 82       1545564.0    10035            116 ST6
# 252       600657.0    10035           116 STBC
# 237       648191.0    10027            125 ST1
# 129      1217065.0    10027           125 ST23
# 27       2699605.0    10027          125 ST456
# 34       2422734.0    10027         125 STACBD
# 147      1111082.0    10030           135 ST23
# 229       688126.0    10030           135 STBC
# 43       2160903.0    10011        14 ST123FLM
# 70       1762991.0    10011          14 STACEL
# 87       1524093.0    10011        14 STFLM123
# 210       768998.0    10031            145 ST1
# 406       268241.0    10031            145 ST3
# 55       1962699.0    10031         145 STABCD
# 392       297557.0    10018           155 STBD
# 425       230640.0    10018            155 STC
# 172       979689.0    10018            157 ST1
# 83       1542391.0    10032          168 STAC1
# 153      1090499.0    10033            175 STA
# 187       898260.0    10018             18 ST1
# 185       910775.0    10033            181 ST1
# 195       835169.0    10033            181 STA
# 337       410733.0    10040            190 STA
# 247       613023.0    10040            191 ST1
# 101      1419402.0    10002              2 AVF
# 245       626818.0    10034            207 ST1
# 453       153939.0    10018            215 ST1
# 132      1199243.0    10011             23 ST1
# 29       2609567.0    10011             23 ST6
# 60       1872824.0    10011            23 STCE
# 33       2427484.0    10011            23 STFM
# 47       2084625.0    10011           23 STNRW
# 138      1166734.0    10001             28 ST1
# 84       1541166.0    10001             28 ST6
# 173       977342.0    10001           28 STNRW
# 331       416449.0    10003              3 AVL
# 40       2200001.0    10018             33 ST6
# 69       1763647.0    10019          49 STNQRW
# 58       1916368.0    10022       5 AV/53 STEM
# 122      1246608.0    10065     5 AV/59 STNQRW
# 50       2051982.0    10019             50 ST1
# 67       1776465.0    10019            50 STCE
# 414       253611.0    10019             50 STD
# 35       2406917.0    10022             51 ST6
# 118      1289111.0    10019             57 STF
# 18       3328368.0    10022       59 ST456NQRW
# 168       993052.0    10022       59 STNQR456W
# 180       940981.0    10022           59 STNRW
# 334       413003.0    10011         6 AVFLM123
# 105      1388532.0    10019            7 AVBDE
# 211       767980.0    10019             7 AVBQ
# 174       966045.0    10019             7 AVFG
# 15       3607329.0    10021           72 ST123
# 212       764861.0    10021            72 STBC
# 51       2041600.0    10075             77 ST6
# 320       436998.0    10075             77 STR
# 133      1189727.0    10024             79 ST1
# 285       504773.0    10024             79 STD
# 61       1858692.0    10011           8 AVACEL
# 167      1005285.0    10011              8 AVN
# 100      1421727.0    10028             86 ST1
# 16       3518649.0    10028           86 ST456
# 188       897309.0    10028            86 STBC
# 438       193073.0    10028             86 STN
# 186       906553.0    10028             86 STR
# 22       2944699.0    10029           96 ST123
# 108      1370791.0    10029             96 ST6
# 207       795770.0    10029            96 STBC
# 106      1377358.0    10003          ASTOR PL6
# 107      1376082.0    10012     BLEECKER ST6DF
# 353       370739.0    10002           BOWERYJZ
# 26       2729008.0    10004    BOWLING GREEN45
# 251       601604.0    10005         BROAD STJZ
# 151      1094968.0    10013          CANAL ST1
# 76       1661289.0    10013        CANAL STACE
# 14       3935409.0    10013    CANAL STJNQRZ6W
# 169       992295.0    10022    CATHEDRAL PKWY1
# 241       637558.0    10022   CATHEDRAL PKWYBC
# 80       1620885.0    10013     CHAMBERS ST123
# 41       2183193.0    10013   CHAMBERS STACE23
# 73       1751258.0    10013   CHAMBERS STJZ456
# 322       435450.0    10013       CITY HALLNRW
# 85       1540896.0    10006    CORTLANDT STRNW
# 268       549554.0    10034        DYCKMAN ST1
# 261       570081.0    10034        DYCKMAN STA
# 150      1103432.0    10002     EAST BROADWAYF
# 317       442509.0    10018       FRANKLIN ST1
# 8        5303970.0    10038  FULTON ST2345ACJZ
# 37       2316426.0    10038  FULTON STACJZ2345
# 287       501853.0    10038         FULTON STG
# 36       2406560.0    10017         GRAND STBD
# 301       478078.0    10017          GRAND STL
# 142      1137830.0    10014        HOUSTON ST1
# 158      1065981.0    10012       PRINCE STNRW
# 219       731973.0    10018         RECTOR ST1
# 283       510752.0    10018       RECTOR STNRW
# 38       2229630.0    10004     SOUTH FERRY1RW
# 184       922902.0    10012         SPRING ST6
# 143      1129678.0    10012        SPRING STCE
# 72       1751322.0    10038          WALL ST23
# 63       1849328.0    10038          WALL ST45

# %%
stations_elev.STATION = stations_elev.STATION.str.upper()

# %%
stations_elev["STATIONLINE"] = stations_elev.STATION+stations_elev.LINENAME

# %%
stations_elev.sort_values("STATIONLINE")
# Out:
#                                STATION  \
# 0                                 1 AV
# 2                               103 ST
# 3                               103 ST
# 1                               103 ST
# 4                               110 ST
# 8         116 ST - COLUMBIA UNIVERSITY
# 7                               116 ST
# 6                               116 ST
# 5                               116 ST
# 11                              125 ST
# 12                              125 ST
# 9                               125 ST
# 10                              125 ST
# 13                              135 ST
# 14                              135 ST
# 15               137 ST - CITY COLLEGE
# 18                    14 ST - UNION SQ
# 19                      14 ST-UNION SQ
# 20                          14 ST/8 AV
# 17                               14 ST
# 16                               14 ST
# 23                              145 ST
# 24                              145 ST
# 21                              145 ST
# 22                              145 ST
# 26                              155 ST
# 25                              155 ST
# 27                              157 ST
# 28               163 ST - AMSTERDAM AV
# 30             168 ST - WASHINGTON HTS
# 29                              168 ST
# 31                              175 ST
# 32                               18 ST
# 34                              181 ST
# 33                              181 ST
# 35                              190 ST
# 36                              191 ST
# 37                                2 AV
# 38                              207 ST
# 39                              215 ST
# 44                               23 ST
# 40                               23 ST
# 42                               23 ST
# 43                               23 ST
# 41                               23 ST
# 47                               28 ST
# 45                               28 ST
# 46                               28 ST
# 48                                3 AV
# 49                               33 ST
# 50                       34 ST - 11 AV
# 51                   34 ST - HERALD SQ
# 52                34 ST - PENN STATION
# 53                     34 ST-HERALD SQ
# 54                  34 ST-HUDSON YARDS
# 55                  34 ST-PENN STATION
# 56                   42 ST - BRYANT PK
# 57   42 ST-PORT AUTHORITY BUS TERMINAL
# 58           47-50 STS-ROCKEFELLER CTR
# 59                               49 ST
# 61                          5 AV/53 ST
# 62                          5 AV/59 ST
# 60                                5 AV
# 64                               50 ST
# 63                               50 ST
# 65                               51 ST
# 67                        57 ST - 7 AV
# 66                               57 ST
# 69             59 ST - COLUMBUS CIRCLE
# 70               59 ST-COLUMBUS CIRCLE
# 68                               59 ST
# 71                                6 AV
# 72                66 ST-LINCOLN CENTER
# 73              68 ST - HUNTER COLLEGE
# 74                                7 AV
# 75                               72 ST
# 77                               72 ST
# 76                               72 ST
# 78                               77 ST
# 79                               79 ST
# 80                                8 AV
# 81                          8 ST - NYU
# 82   81 ST - MUSEUM OF NATURAL HISTORY
# 86                               86 ST
# 83                               86 ST
# 85                               86 ST
# 84                               86 ST
# 87                               96 ST
# 90                               96 ST
# 89                               96 ST
# 88                               96 ST
# 91                            ASTOR PL
# 92                         BLEECKER ST
# 93                              BOWERY
# 94                       BOWLING GREEN
# 95                            BROAD ST
# 96                  BROADWAY-LAFAYETTE
# 97           BROOKLYN BRIDGE-CITY HALL
# 103                           CANAL ST
# 98                            CANAL ST
# 102                           CANAL ST
# 101                           CANAL ST
# 100                           CANAL ST
# 99                            CANAL ST
# 105            CATHEDRAL PKWY (110 ST)
# 104                     CATHEDRAL PKWY
# 106        CENTRAL PARK NORTH (110 ST)
# 107                        CHAMBERS ST
# 109                        CHAMBERS ST
# 108                        CHAMBERS ST
# 110       CHRISTOPHER ST - SHERIDAN SQ
# 111                          CITY HALL
# 112                       CORTLANDT ST
# 113                        DELANCEY ST
# 114                         DYCKMAN ST
# 115                         DYCKMAN ST
# 116                      EAST BROADWAY
# 117                           ESSEX ST
# 118                        FRANKLIN ST
# 121                          FULTON ST
# 122                          FULTON ST
# 119                          FULTON ST
# 120                          FULTON ST
# 123              GRAND CENTRAL - 42 ST
# 124              GRAND CENTRAL - 42 ST
# 125              GRAND CENTRAL - 42 ST
# 126                GRAND CENTRAL-42 ST
# 127                           GRAND ST
# 128                    HARLEM - 148 ST
# 129                         HOUSTON ST
# 130                      INWOOD-207 ST
# 131                 LEXINGTON AV/53 ST
# 132                 LEXINGTON AV/59 ST
# 133                 LEXINGTON AV/63 ST
# 134               MARBLE HILL - 225 ST
# 135                            PARK PL
# 136                          PRINCE ST
# 138                          RECTOR ST
# 137                          RECTOR ST
# 139                   ROOSEVELT ISLAND
# 140                        SOUTH FERRY
# 142                          SPRING ST
# 141                          SPRING ST
# 144                   TIMES SQ - 42 ST
# 145                   TIMES SQ - 42 ST
# 143                   TIMES SQ - 42 ST
# 146                   TIMES SQ - 42 ST
# 147                 TIMES SQUARE-42 ST
# 148                   UNION SQ - 14 ST
# 149                            WALL ST
# 150                            WALL ST
# 151            WEST 4 ST-WASHINGTON SQ
# 152                       WHITEHALL ST
# 153                 WORLD TRADE CENTER
# 154                      WTC CORTLANDT
#
#                                      LINENAME  Elevator  \
# 0                                           L         0
# 2                                           1         0
# 3                                           6         0
# 1                                          BC         0
# 4                                           6         0
# 8                                           1         0
# 7                                          23         0
# 6                                           6         0
# 5                                          BC         0
# 11                                          1         0
# 12                                         23         0
# 9                                    4/5/2006         1
# 10                                    A/C/B/D         1
# 13                                          3         1
# 14                                         BC         0
# 15                                          1         0
# 18                                        456         0
# 19                                  L/N/Q/R/W         1
# 20                                    A/C/E/L         1
# 17                                        123         0
# 16                                         FM         0
# 23                                          1         0
# 24                                          3         0
# 21                                         AC         0
# 22                                         BD         0
# 26                                         BD         0
# 25                                          C         0
# 27                                          1         0
# 28                                          C         0
# 30                                          1         0
# 29              A/C only  1 is not accessible         1
# 31                                          A         1
# 32                                          1         0
# 34                                          1         0
# 33                                          A         0
# 35                                          A         0
# 36                                          1         0
# 37                                          F         0
# 38                                          1         0
# 39                                          1         0
# 44                                          1         0
# 40                                          6         1
# 42                                         CE         0
# 43                                         FM         0
# 41                                         RW         0
# 47                                          1         0
# 45                            6 downtown only         1
# 46                                         RW         0
# 48                                          L         0
# 49                                          6         0
# 50                                          7         0
# 51                                       BDFM         0
# 52                                        123         0
# 53                            B/D/F/M/N/Q/R/W         1
# 54                                          7         1
# 55                                1/2/3/A/C/E         1
# 56                                       BDFM         0
# 57                                      A/C/E         1
# 58                                    B/D/F/M         1
# 59                          N/R/W uptown only         1
# 61                                         EM         0
# 62                                        NWR         0
# 60                                          7         0
# 64                                          1         0
# 63                          C/E downtown only         1
# 65                                          6         1
# 67                                       NQRW         0
# 66                                          F         0
# 69                                          1         0
# 70                                  A/C/B/D/1         1
# 68                                        456         0
# 71                                          L         0
# 72                                          1         1
# 73                                          6         0
# 74                                        BDE         0
# 75                                   1/2/2003         1
# 77                                         BC         0
# 76                                          Q         1
# 78                                          6         0
# 79                                          1         0
# 80                                          L         0
# 81                                         RW         0
# 82                                         BC         0
# 86                                          1         0
# 83                              6 uptown only         1
# 85                                         BC         0
# 84                                          Q         1
# 87                                   1/2/2003         1
# 90                                          6         0
# 89                                         BC         0
# 88                                          Q         1
# 91                                          6         0
# 92                                          6         1
# 93                                         JZ         0
# 94                                          5         1
# 95                                         JZ         0
# 96                                    B/D/F/M         1
# 97                                   4/5/2006         1
# 103                                         1         0
# 98     6 only  J/N/Q/R/W/Z are not accessible         1
# 102                                       ACE         0
# 101                                        JZ         0
# 100                                        NQ         0
# 99                                         RW         0
# 105                                        BC         0
# 104                                         1         0
# 106                                        23         0
# 107                                  1/2/2003         1
# 109                                        AC         0
# 108                                        JZ         0
# 110                                         1         0
# 111                                        RW         0
# 112                                       R/W         1
# 113                                         F         0
# 114                           1 downtown only         1
# 115                                         A         0
# 116                                         F         0
# 117                                       JMZ         0
# 118                                         1         0
# 121                                        23         0
# 122                                        45         0
# 119                           A/C/J/Z/2/3/4/5         1
# 120                                        AC         0
# 123                                       456         0
# 124                                         7         0
# 125                                         S         0
# 126          4/5/6/7 only S is not accessible         1
# 127                                        BD         0
# 128                                         3         0
# 129                                         1         0
# 130                                         A         1
# 131                                       E/M         1
# 132                                       NWR         0
# 133                                       F/Q         1
# 134                                         1         0
# 135                                        23         0
# 136                                        RW         0
# 138                                         1         0
# 137                                        RW         0
# 139                                         F         1
# 140                                         1         1
# 142                                         6         0
# 141                                        CE         0
# 144                                       123         0
# 145                                         7         0
# 143                                      NQRW         0
# 146                                         S         0
# 147  N/Q/R/W/1/2/3/7 only S is not accessible         1
# 148                                         L         0
# 149                                        23         0
# 150                                        45         0
# 151                             A/C/E/B/D/F/M         1
# 152                                        RW         0
# 153                                         E         1
# 154                                         1         1
#
#                                            STATIONLINE
# 0                                                1 AVL
# 2                                              103 ST1
# 3                                              103 ST6
# 1                                             103 STBC
# 4                                              110 ST6
# 8                        116 ST - COLUMBIA UNIVERSITY1
# 7                                             116 ST23
# 6                                              116 ST6
# 5                                             116 STBC
# 11                                             125 ST1
# 12                                            125 ST23
# 9                                       125 ST4/5/2006
# 10                                       125 STA/C/B/D
# 13                                             135 ST3
# 14                                            135 STBC
# 15                              137 ST - CITY COLLEGE1
# 18                                 14 ST - UNION SQ456
# 19                             14 ST-UNION SQL/N/Q/R/W
# 20                                   14 ST/8 AVA/C/E/L
# 17                                            14 ST123
# 16                                             14 STFM
# 23                                             145 ST1
# 24                                             145 ST3
# 21                                            145 STAC
# 22                                            145 STBD
# 26                                            155 STBD
# 25                                             155 STC
# 27                                             157 ST1
# 28                              163 ST - AMSTERDAM AVC
# 30                            168 ST - WASHINGTON HTS1
# 29                 168 STA/C only  1 is not accessible
# 31                                             175 STA
# 32                                              18 ST1
# 34                                             181 ST1
# 33                                             181 STA
# 35                                             190 STA
# 36                                             191 ST1
# 37                                               2 AVF
# 38                                             207 ST1
# 39                                             215 ST1
# 44                                              23 ST1
# 40                                              23 ST6
# 42                                             23 STCE
# 43                                             23 STFM
# 41                                             23 STRW
# 47                                              28 ST1
# 45                                28 ST6 downtown only
# 46                                             28 STRW
# 48                                               3 AVL
# 49                                              33 ST6
# 50                                      34 ST - 11 AV7
# 51                               34 ST - HERALD SQBDFM
# 52                             34 ST - PENN STATION123
# 53                      34 ST-HERALD SQB/D/F/M/N/Q/R/W
# 54                                 34 ST-HUDSON YARDS7
# 55                       34 ST-PENN STATION1/2/3/A/C/E
# 56                               42 ST - BRYANT PKBDFM
# 57              42 ST-PORT AUTHORITY BUS TERMINALA/C/E
# 58                    47-50 STS-ROCKEFELLER CTRB/D/F/M
# 59                              49 STN/R/W uptown only
# 61                                        5 AV/53 STEM
# 62                                       5 AV/59 STNWR
# 60                                               5 AV7
# 64                                              50 ST1
# 63                              50 STC/E downtown only
# 65                                              51 ST6
# 67                                    57 ST - 7 AVNQRW
# 66                                              57 STF
# 69                            59 ST - COLUMBUS CIRCLE1
# 70                      59 ST-COLUMBUS CIRCLEA/C/B/D/1
# 68                                            59 ST456
# 71                                               6 AVL
# 72                               66 ST-LINCOLN CENTER1
# 73                             68 ST - HUNTER COLLEGE6
# 74                                             7 AVBDE
# 75                                       72 ST1/2/2003
# 77                                             72 STBC
# 76                                              72 STQ
# 78                                              77 ST6
# 79                                              79 ST1
# 80                                               8 AVL
# 81                                        8 ST - NYURW
# 82                 81 ST - MUSEUM OF NATURAL HISTORYBC
# 86                                              86 ST1
# 83                                  86 ST6 uptown only
# 85                                             86 STBC
# 84                                              86 STQ
# 87                                       96 ST1/2/2003
# 90                                              96 ST6
# 89                                             96 STBC
# 88                                              96 STQ
# 91                                           ASTOR PL6
# 92                                        BLEECKER ST6
# 93                                            BOWERYJZ
# 94                                      BOWLING GREEN5
# 95                                          BROAD STJZ
# 96                           BROADWAY-LAFAYETTEB/D/F/M
# 97                   BROOKLYN BRIDGE-CITY HALL4/5/2006
# 103                                          CANAL ST1
# 98      CANAL ST6 only  J/N/Q/R/W/Z are not accessible
# 102                                        CANAL STACE
# 101                                         CANAL STJZ
# 100                                         CANAL STNQ
# 99                                          CANAL STRW
# 105                          CATHEDRAL PKWY (110 ST)BC
# 104                                    CATHEDRAL PKWY1
# 106                      CENTRAL PARK NORTH (110 ST)23
# 107                                CHAMBERS ST1/2/2003
# 109                                      CHAMBERS STAC
# 108                                      CHAMBERS STJZ
# 110                      CHRISTOPHER ST - SHERIDAN SQ1
# 111                                        CITY HALLRW
# 112                                    CORTLANDT STR/W
# 113                                       DELANCEY STF
# 114                          DYCKMAN ST1 downtown only
# 115                                        DYCKMAN STA
# 116                                     EAST BROADWAYF
# 117                                        ESSEX STJMZ
# 118                                       FRANKLIN ST1
# 121                                        FULTON ST23
# 122                                        FULTON ST45
# 119                           FULTON STA/C/J/Z/2/3/4/5
# 120                                        FULTON STAC
# 123                           GRAND CENTRAL - 42 ST456
# 124                             GRAND CENTRAL - 42 ST7
# 125                             GRAND CENTRAL - 42 STS
# 126  GRAND CENTRAL-42 ST4/5/6/7 only S is not acces...
# 127                                         GRAND STBD
# 128                                   HARLEM - 148 ST3
# 129                                        HOUSTON ST1
# 130                                     INWOOD-207 STA
# 131                              LEXINGTON AV/53 STE/M
# 132                              LEXINGTON AV/59 STNWR
# 133                              LEXINGTON AV/63 STF/Q
# 134                              MARBLE HILL - 225 ST1
# 135                                          PARK PL23
# 136                                        PRINCE STRW
# 138                                         RECTOR ST1
# 137                                        RECTOR STRW
# 139                                  ROOSEVELT ISLANDF
# 140                                       SOUTH FERRY1
# 142                                         SPRING ST6
# 141                                        SPRING STCE
# 144                                TIMES SQ - 42 ST123
# 145                                  TIMES SQ - 42 ST7
# 143                               TIMES SQ - 42 STNQRW
# 146                                  TIMES SQ - 42 STS
# 147  TIMES SQUARE-42 STN/Q/R/W/1/2/3/7 only S is no...
# 148                                  UNION SQ - 14 STL
# 149                                          WALL ST23
# 150                                          WALL ST45
# 151               WEST 4 ST-WASHINGTON SQA/C/E/B/D/F/M
# 152                                     WHITEHALL STRW
# 153                                WORLD TRADE CENTERE
# 154                                     WTC CORTLANDT1

# %%
elev_dict  = pd.Series(stations_elev.Elevator.values,index=[stations_elev.STATIONLINE]).to_dict()

# %%
elev_dict
# Out:
# {('1 AVL',): 0,
#  ('103 STBC',): 0,
#  ('103 ST1',): 0,
#  ('103 ST6',): 0,
#  ('110 ST6',): 0,
#  ('116 STBC',): 0,
#  ('116 ST6',): 0,
#  ('116 ST23',): 0,
#  ('116 ST - COLUMBIA UNIVERSITY1',): 0,
#  ('125 ST4/5/2006',): 1,
#  ('125 STA/C/B/D',): 1,
#  ('125 ST1',): 0,
#  ('125 ST23',): 0,
#  ('135 ST3',): 1,
#  ('135 STBC',): 0,
#  ('137 ST - CITY COLLEGE1',): 0,
#  ('14 STFM',): 0,
#  ('14 ST123',): 0,
#  ('14 ST - UNION SQ456',): 0,
#  ('14 ST-UNION SQL/N/Q/R/W',): 1,
#  ('14 ST/8 AVA/C/E/L',): 1,
#  ('145 STAC',): 0,
#  ('145 STBD',): 0,
#  ('145 ST1',): 0,
#  ('145 ST3',): 0,
#  ('155 STC',): 0,
#  ('155 STBD',): 0,
#  ('157 ST1',): 0,
#  ('163 ST - AMSTERDAM AVC',): 0,
#  ('168 STA/C only  1 is not accessible',): 1,
#  ('168 ST - WASHINGTON HTS1',): 0,
#  ('175 STA',): 1,
#  ('18 ST1',): 0,
#  ('181 STA',): 0,
#  ('181 ST1',): 0,
#  ('190 STA',): 0,
#  ('191 ST1',): 0,
#  ('2 AVF',): 0,
#  ('207 ST1',): 0,
#  ('215 ST1',): 0,
#  ('23 ST6',): 1,
#  ('23 STRW',): 0,
#  ('23 STCE',): 0,
#  ('23 STFM',): 0,
#  ('23 ST1',): 0,
#  ('28 ST6 downtown only',): 1,
#  ('28 STRW',): 0,
#  ('28 ST1',): 0,
#  ('3 AVL',): 0,
#  ('33 ST6',): 0,
#  ('34 ST - 11 AV7',): 0,
#  ('34 ST - HERALD SQBDFM',): 0,
#  ('34 ST - PENN STATION123',): 0,
#  ('34 ST-HERALD SQB/D/F/M/N/Q/R/W',): 1,
#  ('34 ST-HUDSON YARDS7',): 1,
#  ('34 ST-PENN STATION1/2/3/A/C/E',): 1,
#  ('42 ST - BRYANT PKBDFM',): 0,
#  ('42 ST-PORT AUTHORITY BUS TERMINALA/C/E',): 1,
#  ('47-50 STS-ROCKEFELLER CTRB/D/F/M',): 1,
#  ('49 STN/R/W uptown only',): 1,
#  ('5 AV7',): 0,
#  ('5 AV/53 STEM',): 0,
#  ('5 AV/59 STNWR',): 0,
#  ('50 STC/E downtown only',): 1,
#  ('50 ST1',): 0,
#  ('51 ST6',): 1,
#  ('57 STF',): 0,
#  ('57 ST - 7 AVNQRW',): 0,
#  ('59 ST456',): 0,
#  ('59 ST - COLUMBUS CIRCLE1',): 0,
#  ('59 ST-COLUMBUS CIRCLEA/C/B/D/1',): 1,
#  ('6 AVL',): 0,
#  ('66 ST-LINCOLN CENTER1',): 1,
#  ('68 ST - HUNTER COLLEGE6',): 0,
#  ('7 AVBDE',): 0,
#  ('72 ST1/2/2003',): 1,
#  ('72 STQ',): 1,
#  ('72 STBC',): 0,
#  ('77 ST6',): 0,
#  ('79 ST1',): 0,
#  ('8 AVL',): 0,
#  ('8 ST - NYURW',): 0,
#  ('81 ST - MUSEUM OF NATURAL HISTORYBC',): 0,
#  ('86 ST6 uptown only',): 1,
#  ('86 STQ',): 1,
#  ('86 STBC',): 0,
#  ('86 ST1',): 0,
#  ('96 ST1/2/2003',): 1,
#  ('96 STQ',): 1,
#  ('96 STBC',): 0,
#  ('96 ST6',): 0,
#  ('ASTOR PL6',): 0,
#  ('BLEECKER ST6',): 1,
#  ('BOWERYJZ',): 0,
#  ('BOWLING GREEN5',): 1,
#  ('BROAD STJZ',): 0,
#  ('BROADWAY-LAFAYETTEB/D/F/M',): 1,
#  ('BROOKLYN BRIDGE-CITY HALL4/5/2006',): 1,
#  ('CANAL ST6 only  J/N/Q/R/W/Z are not accessible',): 1,
#  ('CANAL STRW',): 0,
#  ('CANAL STNQ',): 0,
#  ('CANAL STJZ',): 0,
#  ('CANAL STACE',): 0,
#  ('CANAL ST1',): 0,
#  ('CATHEDRAL PKWY1',): 0,
#  ('CATHEDRAL PKWY (110 ST)BC',): 0,
#  ('CENTRAL PARK NORTH (110 ST)23',): 0,
#  ('CHAMBERS ST1/2/2003',): 1,
#  ('CHAMBERS STJZ',): 0,
#  ('CHAMBERS STAC',): 0,
#  ('CHRISTOPHER ST - SHERIDAN SQ1',): 0,
#  ('CITY HALLRW',): 0,
#  ('CORTLANDT STR/W',): 1,
#  ('DELANCEY STF',): 0,
#  ('DYCKMAN ST1 downtown only',): 1,
#  ('DYCKMAN STA',): 0,
#  ('EAST BROADWAYF',): 0,
#  ('ESSEX STJMZ',): 0,
#  ('FRANKLIN ST1',): 0,
#  ('FULTON STA/C/J/Z/2/3/4/5',): 1,
#  ('FULTON STAC',): 0,
#  ('FULTON ST23',): 0,
#  ('FULTON ST45',): 0,
#  ('GRAND CENTRAL - 42 ST456',): 0,
#  ('GRAND CENTRAL - 42 ST7',): 0,
#  ('GRAND CENTRAL - 42 STS',): 0,
#  ('GRAND CENTRAL-42 ST4/5/6/7 only S is not accessible',): 1,
#  ('GRAND STBD',): 0,
#  ('HARLEM - 148 ST3',): 0,
#  ('HOUSTON ST1',): 0,
#  ('INWOOD-207 STA',): 1,
#  ('LEXINGTON AV/53 STE/M',): 1,
#  ('LEXINGTON AV/59 STNWR',): 0,
#  ('LEXINGTON AV/63 STF/Q',): 1,
#  ('MARBLE HILL - 225 ST1',): 0,
#  ('PARK PL23',): 0,
#  ('PRINCE STRW',): 0,
#  ('RECTOR STRW',): 0,
#  ('RECTOR ST1',): 0,
#  ('ROOSEVELT ISLANDF',): 1,
#  ('SOUTH FERRY1',): 1,
#  ('SPRING STCE',): 0,
#  ('SPRING ST6',): 0,
#  ('TIMES SQ - 42 STNQRW',): 0,
#  ('TIMES SQ - 42 ST123',): 0,
#  ('TIMES SQ - 42 ST7',): 0,
#  ('TIMES SQ - 42 STS',): 0,
#  ('TIMES SQUARE-42 STN/Q/R/W/1/2/3/7 only S is not accessible',): 1,
#  ('UNION SQ - 14 STL',): 0,
#  ('WALL ST23',): 0,
#  ('WALL ST45',): 0,
#  ('WEST 4 ST-WASHINGTON SQA/C/E/B/D/F/M',): 1,
#  ('WHITEHALL STRW',): 0,
#  ('WORLD TRADE CENTERE',): 1,
#  ('WTC CORTLANDT1',): 1}

# %%
manh_stations_total["Elev"] = manh_stations_total["STATIONLINE"].map(elev_dict)
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
manh_stations_total
# Out:
#      index    STATION  LINENAME       ENTRIES  PREV_ENTRIES  DAILY_ENTRIES  \
# 8      301  FULTON ST  2345ACJZ  141641492745  1.416370e+11      5303970.0
# 14     234   CANAL ST   JNQRZ6W  275657025992  2.756537e+11      3935409.0
# 15     138      72 ST       123   68243510585  6.824090e+10      3607329.0
# 16     156      86 ST       456  119545892760  1.195424e+11      3518649.0
# 18     121      59 ST   456NQRW  151409177842  1.521094e+11      3328368.0
# ..     ...        ...       ...           ...           ...            ...
# 406     30     145 ST         3    1333200594  1.332932e+09       268241.0
# 414    114      50 ST         D    1145424833  1.145171e+09       253611.0
# 425     36     155 ST         C    1479960900  1.479730e+09       230640.0
# 438    158      86 ST         N     451371746  4.511787e+08       193073.0
# 453     67     215 ST         1     703569282  7.034153e+08       153939.0
#
#      ZipCode        STATIONLINE  Elev
# 8      10038  FULTON ST2345ACJZ   NaN
# 14     10013    CANAL STJNQRZ6W   NaN
# 15     10021           72 ST123   NaN
# 16     10028           86 ST456   NaN
# 18     11234       59 ST456NQRW   NaN
# ..       ...                ...   ...
# 406    10031            145 ST3   NaN
# 414    10019             50 STD   NaN
# 425    10018            155 STC   NaN
# 438    10028             86 STN   NaN
# 453    10018            215 ST1   NaN
#
# [107 rows x 9 columns]

# %%
manh_stations_total
# Out:
#      index    STATION  LINENAME       ENTRIES  PREV_ENTRIES  DAILY_ENTRIES  \
# 8      301  FULTON ST  2345ACJZ  141641492745  1.416370e+11      5303970.0
# 14     234   CANAL ST   JNQRZ6W  275657025992  2.756537e+11      3935409.0
# 15     138      72 ST       123   68243510585  6.824090e+10      3607329.0
# 16     156      86 ST       456  119545892760  1.195424e+11      3518649.0
# 18     121      59 ST   456NQRW  151409177842  1.521094e+11      3328368.0
# ..     ...        ...       ...           ...           ...            ...
# 406     30     145 ST         3    1333200594  1.332932e+09       268241.0
# 414    114      50 ST         D    1145424833  1.145171e+09       253611.0
# 425     36     155 ST         C    1479960900  1.479730e+09       230640.0
# 438    158      86 ST         N     451371746  4.511787e+08       193073.0
# 453     67     215 ST         1     703569282  7.034153e+08       153939.0
#
#      ZipCode  Elev
# 8      10038   1.0
# 14     10013   1.0
# 15     10021   1.0
# 16     10028   1.0
# 18     11234   NaN
# ..       ...   ...
# 406    10031   NaN
# 414    10019   1.0
# 425    10018   NaN
# 438    10028   1.0
# 453    10018   NaN
#
# [107 rows x 8 columns]

# %%
#Map disability and age #s

# %%
age_disability = pd.read_csv("zip_code_age_disability_df.csv")

# %%
age_disability
# Out:
#     ZipCode     aged  disabled
# 0     10001   5297.0    3475.0
# 1     10002  23825.0   24260.0
# 2     10003  11020.0    5624.0
# 3     10004    540.0     169.0
# 4     10005    669.0     154.0
# 5     10006    377.0       0.0
# 6     10007   1231.0     170.0
# 7     10009  13667.0   13695.0
# 8     10010   7523.0    4206.0
# 9     10011  13260.0    7709.0
# 10    10012   5252.0    2307.0
# 11    10013   8071.0    5060.0
# 12    10014   7678.0    2914.0
# 13    10016  11458.0    6420.0
# 14    10017   4720.0    1938.0
# 15    10018   1339.0     921.0
# 16    10019  10479.0    7301.0
# 17    10020      NaN       NaN
# 18    10021  15250.0    5634.0
# 19    10022  12087.0    4602.0
# 20    10023  21116.0    9738.0
# 21    10024  19019.0    8657.0
# 22    10025  28931.0   17545.0
# 23    10026   8506.0    8112.0
# 24    10027  12631.0   11386.0
# 25    10028  13422.0    4568.0
# 26    10029  18966.0   24241.0
# 27    10030   7110.0    9215.0
# 28    10031  13199.0   12668.0
# 29    10032  14424.0   18119.0
# 30    10033  14882.0   15222.0
# 31    10034  10983.0    9624.0
# 32    10035   8515.0   10825.0
# 33    10036   5890.0    4501.0
# 34    10037   6089.0    3981.0
# 35    10038   6151.0    4893.0
# 36    10039   6223.0    6169.0
# 37    10040  12010.0    9692.0
# 38    10044   3531.0    1470.0
# 39    10065   9214.0    2845.0
# 40    10075   7999.0    2893.0
# 41    10128      NaN       NaN
# 42    10280   1944.0     432.0

# %%
aged_dict  = pd.Series(age_disability.aged.values,index=age_disability.ZipCode).to_dict()

# %%
manh_stations_total["aged"] = manh_stations_total["ZipCode"].map(aged_dict)
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
disabled_dict = pd.Series(age_disability.disabled.values,index=age_disability.ZipCode).to_dict()

# %%
manh_stations_total["disabled"] = manh_stations_total["ZipCode"].map(disabled_dict)
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
manh_stations_total["aged_scaled"] = manh_stations_total["aged"]/max(manh_stations_total.aged)
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
manh_stations_total["disabled_scaled"] = manh_stations_total["disabled"]/max(manh_stations_total.disabled)
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
manh_stations_total["entries_scaled"] = manh_stations_total["DAILY_ENTRIES"]/max(manh_stations_total.DAILY_ENTRIES)
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
manh_stations_total["Neediness"] = (manh_stations_total.aged_scaled + manh_stations_total.disabled_scaled + manh_stations_total.entries_scaled)/3
# Out:
# C:\Users\tskth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
manh_stations_total
# Out:
#      index    STATION  LINENAME       ENTRIES  PREV_ENTRIES  DAILY_ENTRIES  \
# 8      301  FULTON ST  2345ACJZ  141641492745  1.416370e+11      5303970.0
# 14     234   CANAL ST   JNQRZ6W  275657025992  2.756537e+11      3935409.0
# 15     138      72 ST       123   68243510585  6.824090e+10      3607329.0
# 16     156      86 ST       456  119545892760  1.195424e+11      3518649.0
# 18     121      59 ST   456NQRW  151409177842  1.521094e+11      3328368.0
# ..     ...        ...       ...           ...           ...            ...
# 406     30     145 ST         3    1333200594  1.332932e+09       268241.0
# 414    114      50 ST         D    1145424833  1.145171e+09       253611.0
# 425     36     155 ST         C    1479960900  1.479730e+09       230640.0
# 438    158      86 ST         N     451371746  4.511787e+08       193073.0
# 453     67     215 ST         1     703569282  7.034153e+08       153939.0
#
#      ZipCode  Elev     aged  disabled  aged_scaled  disabled_scaled  \
# 8      10038   1.0   6151.0    4893.0     0.258174         0.201690
# 14     10013   1.0   8071.0    5060.0     0.338762         0.208574
# 15     10021   1.0  15250.0    5634.0     0.640084         0.232234
# 16     10028   1.0  13422.0    4568.0     0.563358         0.188293
# 18     11234   NaN      NaN       NaN          NaN              NaN
# ..       ...   ...      ...       ...          ...              ...
# 406    10031   NaN  13199.0   12668.0     0.553998         0.522176
# 414    10019   1.0  10479.0    7301.0     0.439832         0.300948
# 425    10018   NaN   1339.0     921.0     0.056201         0.037964
# 438    10028   1.0  13422.0    4568.0     0.563358         0.188293
# 453    10018   NaN   1339.0     921.0     0.056201         0.037964
#
#      entries_scaled  Neediness
# 8          1.000000   0.486621
# 14         0.741974   0.429770
# 15         0.680119   0.517479
# 16         0.663399   0.471683
# 18         0.627524        NaN
# ..              ...        ...
# 406        0.050574   0.375583
# 414        0.047815   0.262865
# 425        0.043484   0.045883
# 438        0.036402   0.262684
# 453        0.029023   0.041063
#
# [107 rows x 14 columns]

# %%
#Sort by neediest stations

manh_stations_total.sort_values("Neediness", ascending = False)
# Out:
#      index        STATION LINENAME       ENTRIES  PREV_ENTRIES  DAILY_ENTRIES  \
# 22     164          96 ST      123   14946269851  1.494333e+10      2944699.0
# 150    277  EAST BROADWAY        F   13818349792  1.381725e+10      1103432.0
# 353    216         BOWERY       JZ    1541058079  1.540687e+09       370739.0
# 108    165          96 ST        6   66002402621  6.600103e+10      1370791.0
# 192      7         110 ST        6    3525627318  3.524766e+09       861425.0
# ..     ...            ...      ...           ...           ...            ...
# 171      1         103 ST        1    5901511168  5.900530e+09       981372.0
# 180    123          59 ST      NRW    1350710638  1.349770e+09       940981.0
# 331     83           3 AV        L    2334083753  2.333667e+09       416449.0
# 334    126           6 AV   FLM123  110323108488  1.103231e+11       413003.0
# 347      3         103 ST       BC    2747657700  2.747271e+09       386482.0
#
#      ZipCode  Elev     aged  disabled  aged_scaled  disabled_scaled  \
# 22     10029   1.0  18966.0   24241.0     0.796055         0.999217
# 150    10002   NaN  23825.0   24260.0     1.000000         1.000000
# 353    10002   NaN  23825.0   24260.0     1.000000         1.000000
# 108    10029   1.0  18966.0   24241.0     0.796055         0.999217
# 192    10029   NaN  18966.0   24241.0     0.796055         0.999217
# ..       ...   ...      ...       ...          ...              ...
# 171    11368   NaN      NaN       NaN          NaN              NaN
# 180    11234   NaN      NaN       NaN          NaN              NaN
# 331    11372   NaN      NaN       NaN          NaN              NaN
# 334    11372   NaN      NaN       NaN          NaN              NaN
# 347    11368   NaN      NaN       NaN          NaN              NaN
#
#      entries_scaled  Neediness
# 22         0.555188   0.783486
# 150        0.208039   0.736013
# 353        0.069898   0.689966
# 108        0.258446   0.684573
# 192        0.162411   0.652561
# ..              ...        ...
# 171        0.185026        NaN
# 180        0.177411        NaN
# 331        0.078516        NaN
# 334        0.077867        NaN
# 347        0.072867        NaN
#
# [107 rows x 14 columns]

# %%
#Neediest stations that do not already have an elevator:

manh_stations_total[manh_stations_total.Elev != 1].sort_values("Neediness", ascending = False)
# Out:
#      index        STATION LINENAME       ENTRIES  PREV_ENTRIES  DAILY_ENTRIES  \
# 150    277  EAST BROADWAY        F   13818349792  1.381725e+10      1103432.0
# 353    216         BOWERY       JZ    1541058079  1.540687e+09       370739.0
# 192      7         110 ST        6    3525627318  3.524766e+09       861425.0
# 55      31         145 ST     ABCD   10532589724  1.053063e+10      1962699.0
# 185     55         181 ST        1    3345058744  3.344148e+09       910775.0
# ..     ...            ...      ...           ...           ...            ...
# 171      1         103 ST        1    5901511168  5.900530e+09       981372.0
# 180    123          59 ST      NRW    1350710638  1.349770e+09       940981.0
# 331     83           3 AV        L    2334083753  2.333667e+09       416449.0
# 334    126           6 AV   FLM123  110323108488  1.103231e+11       413003.0
# 347      3         103 ST       BC    2747657700  2.747271e+09       386482.0
#
#      ZipCode  Elev     aged  disabled  aged_scaled  disabled_scaled  \
# 150    10002   NaN  23825.0   24260.0     1.000000         1.000000
# 353    10002   NaN  23825.0   24260.0     1.000000         1.000000
# 192    10029   NaN  18966.0   24241.0     0.796055         0.999217
# 55     10031   NaN  13199.0   12668.0     0.553998         0.522176
# 185    10033   NaN  14882.0   15222.0     0.624638         0.627453
# ..       ...   ...      ...       ...          ...              ...
# 171    11368   NaN      NaN       NaN          NaN              NaN
# 180    11234   NaN      NaN       NaN          NaN              NaN
# 331    11372   NaN      NaN       NaN          NaN              NaN
# 334    11372   NaN      NaN       NaN          NaN              NaN
# 347    11368   NaN      NaN       NaN          NaN              NaN
#
#      entries_scaled  Neediness
# 150        0.208039   0.736013
# 353        0.069898   0.689966
# 192        0.162411   0.652561
# 55         0.370043   0.482073
# 185        0.171716   0.474602
# ..              ...        ...
# 171        0.185026        NaN
# 180        0.177411        NaN
# 331        0.078516        NaN
# 334        0.077867        NaN
# 347        0.072867        NaN
#
# [61 rows x 14 columns]
