# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import datetime

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
sns.set(color_codes=True)
plt.style.use('seaborn-colorblind')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.precision', 2)

# %%
with open('combined_binh_eliza_df.pickle', 'rb') as read_file:
    combined_binh_eliza = pickle.load(read_file)

# %%
combined_binh_eliza.head()
# Out:
#   zip_code  actual_population  percent_disabled  percent_under_age_5  \
# 0    10001            22924.0             15.16                 2.06
# 1    10002            74993.0             32.35                 3.52
# 2    10003            54682.0             10.28                 3.23
# 3    10004             3028.0              5.58                 4.13
# 4    10005             8831.0              1.74                 5.91
#
#    percent_over_age_60  percent_age_under_5_over_60  \
# 0                21.05                        23.11
# 1                28.25                        31.77
# 2                16.92                        20.15
# 3                13.71                        17.83
# 4                 1.66                         7.58
#
#    Sample population with a cognitive difficulty  \
# 0                                          745.0
# 1                                         4579.0
# 2                                         1426.0
# ...

# %%
relevant_columns = ['zip_code', 'actual_population_under_age_5_over_60', 'actual_population_disabled']
zip_code_age_disability = combined_binh_eliza[relevant_columns]

# %%
zip_code_age_disability.to_csv('zip_code_age_disability_df.csv')

# %%
# !ls
# Out:
# Analyzing Population by Manhattan Zip Code (Binh).ipynb
# Cleaning Population Zip Code Data (Binh).ipynb
# Comparing Binh and Eliza Population Data (Binh).ipynb
# Creating Zip Code.Age.Disability df.ipynb
# Primary.ipynb
# README.md
# Station_Elevator.csv
# Stations With No Elevator2.csv
# Stations with Elevators (Meehir).csv
# combined_binh_eliza_df.pickle
# sub_st_zip.csv
# subway zip code api.ipynb
# zip_code_age_disability_df.csv
